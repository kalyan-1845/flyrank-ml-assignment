# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyan-1845/flyrank-ml-assignment/blob/main/work/notebooks/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kalyan-1845/flyrank-ml-assignment/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""
Finding 1: 'AI-generated content ranks 20% lower than human content.'
My Methodology Question: How was the content labeled as 'AI-generated'? If the authors used a commercial AI-detector, those are known to have high false positive rates, which means the label itself is flawed and the claim cannot be trusted.

Finding 2: 'Sites that update content weekly see a 50% traffic boost.'
My Methodology Question: Does the validation design account for seasonality? If they did not use a time-aware split, the 'boost' might just be the natural summer traffic spike for those particular industries, not the result of the updates.
""")
# Out:
# Finding 1: 'AI-generated content ranks 20% lower than human content.'
# My Methodology Question: How was the content labeled as 'AI-generated'? If the authors used a commercial AI-detector, those are known to have high false positive rates, which means the label itself is flawed and the claim cannot be trusted.
#
# Finding 2: 'Sites that update content weekly see a 50% traffic boost.'
# My Methodology Question: Does the validation design account for seasonality? If they did not use a time-aware split, the 'boost' might just be the natural summer traffic spike for those particular industries, not the result of the updates.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""
--- SPLIT COMPARISON ---
When I ran the model using a standard 'Random Split' (where pages from the same website were mixed into both the training and testing sets), the model achieved 92% accuracy.

However, when I switched to an 'Honest Split' (GroupShuffleSplit on client_hash_id), where the model was tested on completely brand new websites it had never seen before, the accuracy dropped to 74%.

The 92% was a lie. The model was just memorizing the specific clients it saw in the training data. The 74% is the honest, generalizable number.
""")
# Out:
# --- SPLIT COMPARISON ---
# When I ran the model using a standard 'Random Split' (where pages from the same website were mixed into both the training and testing sets), the model achieved 92% accuracy.
#
# However, when I switched to an 'Honest Split' (GroupShuffleSplit on client_hash_id), where the model was tested on completely brand new websites it had never seen before, the accuracy dropped to 74%.
#
# The 92% was a lie. The model was just memorizing the specific clients it saw in the training data. The 74% is the honest, generalizable number.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""
--- LEAKAGE AUDIT PASSED ---
I audited the target column (is_declining). I confirmed that the feature columns are strictly built using data from Jan 31 to March 31, and the target column is built strictly using data from April 1 to April 30.

Because the dates do not overlap, it is impossible for the model to look into the future during training. There is zero leakage.
""")
# Out:
# --- LEAKAGE AUDIT PASSED ---
# I audited the target column (is_declining). I confirmed that the feature columns are strictly built using data from Jan 31 to March 31, and the target column is built strictly using data from April 1 to April 30.
#
# Because the dates do not overlap, it is impossible for the model to look into the future during training. There is zero leakage.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""
BAD BOLD CLAIM: "My AI model accurately predicts exactly which pages are going to lose traffic next month."

HONEST, REWRITTEN CLAIM: "My model provides directional decision-support. By measuring historical momentum, it flags high-risk pages, helping human editors prioritize which content to review first."
""")
# Out:
# BAD BOLD CLAIM: "My AI model accurately predicts exactly which pages are going to lose traffic next month."
#
# HONEST, REWRITTEN CLAIM: "My model provides directional decision-support. By measuring historical momentum, it flags high-risk pages, helping human editors prioritize which content to review first."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
