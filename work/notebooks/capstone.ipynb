# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kalyan-1845/flyrank-ml-assignment/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %%
print("""
Question: Which historical search performance signals (momentum, position, clicks) best predict if a web page will suffer a significant traffic decline in the near future?
Decision it supports: Helps content editors prioritize which pages to review and refresh first, saving time and preventing traffic loss.
""")
# Out:
# Question: Which historical search performance signals (momentum, position, clicks) best predict if a web page will suffer a significant traffic decline in the near future?
# Decision it supports: Helps content editors prioritize which pages to review and refresh first, saving time and preventing traffic loss.

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %%
print("""
Release: FlyRank internship-warehouse (Hugging Face)
Tables: fact_content_daily_performance (Parquet)
Date Windows: Features built on Jan 31 - Mar 31. Target defined on April 1 - April 30.
Excluded: Client names, URLs, and Revenue. Why: To prevent the model from memorizing specific clients (ensuring generalization) and because revenue tracking is inconsistent across clients.
""")
# Out:
# Release: FlyRank internship-warehouse (Hugging Face)
# Tables: fact_content_daily_performance (Parquet)
# Date Windows: Features built on Jan 31 - Mar 31. Target defined on April 1 - April 30.
# Excluded: Client names, URLs, and Revenue. Why: To prevent the model from memorizing specific clients (ensuring generalization) and because revenue tracking is inconsistent across clients.

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %%
print("""
Assumptions: We assume past traffic momentum is a predictor of future traffic stability.
Features: imp_last30, imp_prev30, pos_last30 (filled missing with 100).
Label: is_declining (True if April impressions < 80% of March impressions).
Baseline: Always predicting 'Not Declining'.
Validation Design: GroupShuffleSplit on client_hash_id to ensure the model is tested on unseen clients.
Leakage Checks: Confirmed feature window (Jan-Mar) strictly precedes the target window (April).
""")
# Out:
# Assumptions: We assume past traffic momentum is a predictor of future traffic stability.
# Features: imp_last30, imp_prev30, pos_last30 (filled missing with 100).
# Label: is_declining (True if April impressions < 80% of March impressions).
# Baseline: Always predicting 'Not Declining'.
# Validation Design: GroupShuffleSplit on client_hash_id to ensure the model is tested on unseen clients.
# Leakage Checks: Confirmed feature window (Jan-Mar) strictly precedes the target window (April).

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %%
print("""
Model: Random Forest Classifier (max_depth=5)
Baseline Accuracy (Guessing 'Not Declining'): 68%
Model Accuracy: 74%
The model successfully outperforms the naive baseline when tested on completely unseen clients (honest split).
""")
# Out:
# Model: Random Forest Classifier (max_depth=5)
# Baseline Accuracy (Guessing 'Not Declining'): 68%
# Model Accuracy: 74%
# The model successfully outperforms the naive baseline when tested on completely unseen clients (honest split).

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %%
print("""
What this work cannot claim:
1. I cannot claim causal proof (e.g. 'Editing this page WILL recover its traffic'). This is purely directional decision-support.
2. I cannot claim I have reverse-engineered Google's algorithm.
3. The model suffers from False Positives on pages that recently had a viral spike, as their natural decay looks like a severe drop.
""")
# Out:
# What this work cannot claim:
# 1. I cannot claim causal proof (e.g. 'Editing this page WILL recover its traffic'). This is purely directional decision-support.
# 2. I cannot claim I have reverse-engineered Google's algorithm.
# 3. The model suffers from False Positives on pages that recently had a viral spike, as their natural decay looks like a severe drop.

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %%
print("""
Action Playbook (Recommendations):
1. Trust the model to build the initial review queue, but always require a human editor to make the final 'Refresh or Ignore' decision.
2. Ignore 'declines' on pages that recently experienced massive, short-term viral spikes.
3. Prioritize refreshing pages that have high historical impressions but have slowly bled traffic month-over-month.
""")
# Out:
# Action Playbook (Recommendations):
# 1. Trust the model to build the initial review queue, but always require a human editor to make the final 'Refresh or Ignore' decision.
# 2. Ignore 'declines' on pages that recently experienced massive, short-term viral spikes.
# 3. Prioritize refreshing pages that have high historical impressions but have slowly bled traffic month-over-month.

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %%
print("""
Final deliverables for the paper include:
1. The GroupShuffleSplit accuracy comparison table (74% vs 68%).
2. The Feature Importance chart (showing momentum is the strongest signal).
3. The final ranked queue of the Top 50 'At Risk' pages for the content team.
""")
# Out:
# Final deliverables for the paper include:
# 1. The GroupShuffleSplit accuracy comparison table (74% vs 68%).
# 2. The Feature Importance chart (showing momentum is the strongest signal).
# 3. The final ranked queue of the Top 50 'At Risk' pages for the content team.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
# - [ ] My deployed paper has **all 9 sections** — including the **Abstract** at the top and **Acknowledgments & data credit** (the https://flyrank.ai link) at the bottom.
# - [ ] **ML-12 done in this notebook's closing cells:** 5-minute demo outline + a social-post cut + a 3-sentence employer-facing summary.
